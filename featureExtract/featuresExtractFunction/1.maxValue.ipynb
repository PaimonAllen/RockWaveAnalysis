# %%
# Maximum Value

# test for one data
# load data
import numpy as np

y1 = np.loadtxt("../../1.shapeClassification/KNN/dataset/processAndTemp/1.shapeTotal/1-1")
print(y1.shape)
print(max(y1))
# Out:
# (8192,)
# 0.7793992757797241

# %%
# features extract: maxValue
import numpy as np
from os import listdir
import sys
FileList = listdir('/home/tzr/DataLinux/Documents/GitHubSYNC/RockWaveAnalysis/1.shapeClassification/KNN/dataset/processAndTemp/1.shapeTotal/')
# 返回文件夹下文件的个数
m = len(FileList)
# print(FileList)
print(m)
# sys.exit()
for i in range(m):
    # 获得文件的名字
    fileNameStr = FileList[i]
    # 获得分类的数字
    classNumber = int(fileNameStr.split('-')[1])
    if classNumber == 1:
        data = np.loadtxt(f"/home/tzr/DataLinux/Documents/GitHubSYNC/RockWaveAnalysis/1.shapeClassification/KNN/dataset/processAndTemp/1.shapeTotal/{fileNameStr}")
        # print(data)
        max_value = max(data)
        # min_value = min(data)
        # print(min(data))
        # print(max_value)
        # print(min_value)
        saveArr = [max_value, 1]
        saveArr = np.array(saveArr, dtype=float).reshape(1, 2)
        print(saveArr)
        print(saveArr.ndim)
        # saveClassName = np.array([1], dtype=int)
        with open("../data/1.maxValue.txt", 'a+') as f:
            np.savetxt(f, saveArr, delimiter=',')
            # # np.savetxt(f,)
            # np.savetxt(f, saveClassName)

        # with open("./dataset/rockshape/features_extract/test1.csv", 'a+') as f:
    elif classNumber == 2:
        data = np.loadtxt(f"/home/tzr/DataLinux/Documents/GitHubSYNC/RockWaveAnalysis/1.shapeClassification/KNN/dataset/processAndTemp/1.shapeTotal/{fileNameStr}")
        # print(data)
        max_value = max(data)
        # min_value = min(data)
        # print(min(data))
        # print(max_value)
        # print(min_value)
        saveArr = [max_value, 2]
        saveArr = np.array(saveArr, dtype=float).reshape(1, 2)
        print(saveArr)
        print(saveArr.ndim)
        # saveClassName = np.array([1], dtype=int)
        with open("../data/1.maxValue.txt", 'a+') as f:
            np.savetxt(f, saveArr, delimiter=',')
            # # np.savetxt(f,)
            # np.savetxt(f, saveClassName)

        # with open("./dataset/rockshape/features_extract/test1.csv", 'a+') as f:
# Out:
# 32532
# [[1.36394882 2.        ]]
# 2
# [[0.31663096 1.        ]]
# 2
# [[0.42318946 1.        ]]
# 2
# [[0.42318946 1.        ]]
# 2
# [[0.7702657 1.       ]]
# 2
# [[2.07636857 2.        ]]
# 2
# [[0.38969964 1.        ]]
# 2
# [[1.21781135 2.        ]]
# 2
# [[0.42318946 1.        ]]
# 2
# [[2.07027936 2.        ]]
# 2
# [[1.38221598 2.        ]]
# 2
# [[0.32272005 1.        ]]
# 2
# [[0.39274418 1.        ]]
# 2
# [[1.18127716 2.        ]]
# 2
# [[0.75199854 1.        ]]
# 2
# [[1.19954431 2.        ]]
# 2
# [[1.29392469 2.        ]]
# 2
# [[1.36090422 2.        ]]
# 2
# [[0.75808764 1.        ]]
# 2
# [[0.31967548 1.        ]]
# 2
# [[1.36394882 2.        ]]
# 2
# [[1.26043487 2.        ]]
# 2
# [[0.31358644 1.        ]]
# 2
# [[1.2908802 2.       ]]
# 2
# [[0.42318946 1.        ]]
# 2
# [[1.23303401 2.        ]]
# 2
# [[0.32272005 1.        ]]
# 2
# [[0.38969964 1.        ]]
# 2
# [[0.42318946 1.        ]]
# 2
# [[2.06419039 2.        ]]
# 2
# [[0.39883325 1.        ]]
# 2
# ...
