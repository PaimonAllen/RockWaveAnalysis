# %%
# create vector
# -*- coding: UTF-8 -*-
import numpy as np
import operator
from os import listdir
from sklearn.neighbors import KNeighborsClassifier as kNN

"""
函数说明:向量转化。

Parameters:
    filename - 文件名
Returns:
    returnVect - 返回的二进制原始波形图像的向量

Modify:
    ---
"""

def vector(filename):
    # 创建向量
    returnVect = np.zeros((1, 8192))
    # print(returnVect)
    # 打开文件
    fr = open(filename)
    # 按行读取
    for i in range(8192):
        # 读一行数据
        lineStr = fr.readline().strip("\n")
        # print(lineStr)
        # 每一行的前32个元素依次添加到returnVect中
        returnVect[0][i] = lineStr
    # 返回转换后的向量
    print(returnVect)
    return returnVect
print(vector("../dataset/train1/1-1").shape)
# Out:
# [[0.         0.         0.         ... 0.00304453 0.00304453 0.        ]]
# (1, 8192)

# %%
# main KNN function
# -*- coding: UTF-8 -*-
import numpy as np
import operator
from os import listdir
from sklearn.neighbors import KNeighborsClassifier as kNN

"""
函数说明:向量转化。

Parameters:
    filename - 文件名
Returns:
    returnVect - 返回的二进制图像的向量

Modify:
    ---
"""


def vector(filename):
    # 创建向量
    returnVect = np.zeros((1, 8192))
    # print(returnVect)
    # 打开文件
    fr = open(filename)
    # 按行读取
    for i in range(8192):
        # 读一行数据
        lineStr = fr.readline().strip("\n")
        # print(lineStr)
        # 每一行的元素依次添加到returnVect中
        returnVect[0][i] = lineStr
    # 返回转换后的向量
    # print(returnVect)
    return returnVect


"""
函数说明:分类测试

Parameters:
    无
Returns:
    无

Modify:
    ---
"""
# train序列集合
trainSet = []
# test序列集合
testSet = []
testRes = []


def KNNclassify():
    # 测试集的Labels
    Labels = []
    # 返回trainingDigits目录下的文件名
    trainingFileList = listdir('../dataset/train1/')
    # print(trainingFileList)
    # 返回文件夹下文件的个数
    m = len(trainingFileList)
    print(m)
    # 初始化训练的Mat矩阵,测试集
    trainingMat = np.zeros((m, 8192))
    # 从文件名中解析出训练集的类别
    for i in range(m):
        # 获得文件的名字
        fileNameStr = trainingFileList[i]
        # 获得分类的数字
        classNumber = int(fileNameStr.split('-')[1])
        # 将获得的类别添加到Labels中
        Labels.append(classNumber)
        # 加入train矩阵
        trainSet.append([fileNameStr.split('-')[0], fileNameStr.split('-')[1]])
        # 将每一个文件的数据存储到trainingMat矩阵中
        trainingMat[i, :] = vector(
            '../dataset/train1/%s' % (fileNameStr))
        # print(i)
    # print(trainingMat.shape)
    # print(trainSet)
    # 构建kNN分类器
    neigh = kNN(n_neighbors=1, algorithm='auto')
    #拟合模型, trainingMat为训练矩阵,Labels为对应的标签
    neigh.fit(trainingMat, Labels)
    # 返回testDigits目录下的文件列表
    testFileList = listdir('../dataset/test1/')
    # 错误检测计数
    errorCount = 0.0
    # 测试数据的数量
    mTest = len(testFileList)
    print(mTest)
    # 从文件中解析出测试集的类别并进行分类测试
    for i in range(mTest):
        # 获得文件的名字
        fileNameStr = testFileList[i]
        # 获得分类的数字
        classNumber = int(fileNameStr.split('-')[1])
        # print(classNumber)
        # 获得测试集的1x1024向量,用于训练
        vectorUnderTest = vector(
            '../dataset/test1/%s' % (fileNameStr))
        # 获得预测结果
        # classifierResult = classify0(vectorUnderTest, trainingMat, hwLabels, 3)
        classifierResult = neigh.predict(vectorUnderTest)
        print(classifierResult)
        if classifierResult == 1:
            res = 'square'
            # 加入结果矩阵
            # testSet.append([fileNameStr.split('-')[0], '1'])
        if classifierResult == 2:
            res = 'circle'
            # 加入结果矩阵
            # testSet.append([fileNameStr.split('-')[0], '2'])
        if classNumber == 1:
            rockclass = 'square'
        if classNumber == 2:
            rockclass = 'circle'
        print("分类返回结果为%s\t真实结果为%s" % (res, rockclass))
        if (classifierResult != classNumber):
            errorCount += 1.0
        print("目前错误个数：", errorCount)
        print("process:{:.2f}%".format((i/mTest)*100))
    print("总共错了%d个数据\n错误率为%f%%，正确率为%f%%" %
          (errorCount, errorCount/mTest * 100, (1 - errorCount/mTest) * 100))


"""
函数说明:main函数

Parameters:
    无
Returns:
    无

Modify:
    ---
"""
if __name__ == '__main__':
    KNNclassify()
# Out:
# 160
# 40
# [1]
# 分类返回结果为square	真实结果为square
# 目前错误个数： 0.0
# process:0.0%
# [1]
# 分类返回结果为square	真实结果为square
# 目前错误个数： 0.0
# process:2.5%
# [2]
# 分类返回结果为circle	真实结果为circle
# 目前错误个数： 0.0
# process:5.0%
# [1]
# 分类返回结果为square	真实结果为square
# 目前错误个数： 0.0
# process:7.5%
# [2]
# 分类返回结果为circle	真实结果为circle
# 目前错误个数： 0.0
# process:10.0%
# [2]
# 分类返回结果为circle	真实结果为circle
# 目前错误个数： 0.0
# process:12.5%
# [1]
# 分类返回结果为square	真实结果为square
# 目前错误个数： 0.0
# process:15.0%
# [2]
# 分类返回结果为circle	真实结果为circle
# 目前错误个数： 0.0
# process:17.5%
# [2]
# 分类返回结果为circle	真实结果为circle
# 目前错误个数： 0.0
# process:20.0%
# [1]
# 分类返回结果为square	真实结果为square
# 目前错误个数： 0.0
# process:22.5%
# [2]
# 分类返回结果为circle	真实结果为circle
# 目前错误个数： 0.0
# process:25.0%
# [1]
# 分类返回结果为square	真实结果为square
# 目前错误个数： 0.0
# process:27.500000000000004%
# [1]
# 分类返回结果为square	真实结果为square
# 目前错误个数： 0.0
# process:30.0%
# [2]
# 分类返回结果为circle	真实结果为circle
# 目前错误个数： 0.0
# process:32.5%
# [2]
# 分类返回结果为circle	真实结果为circle
# 目前错误个数： 0.0
# process:35.0%
# [1]
# 分类返回结果为square	真实结果为square
# 目前错误个数： 0.0
# process:37.5%
# [1]
# 分类返回结果为square	真实结果为square
# 目前错误个数： 0.0
# process:40.0%
# [1]
# 分类返回结果为square	真实结果为square
# 目前错误个数： 0.0
# process:42.5%
# [2]
# 分类返回结果为circle	真实结果为circle
# 目前错误个数： 0.0
# process:45.0%
# [1]
# 分类返回结果为square	真实结果为square
# 目前错误个数： 0.0
# process:47.5%
# [2]
# 分类返回结果为circle	真实结果为circle
# 目前错误个数： 0.0
# process:50.0%
# [2]
# 分类返回结果为circle	真实结果为circle
# 目前错误个数： 0.0
# process:52.5%
# [2]
# 分类返回结果为circle	真实结果为circle
# 目前错误个数： 0.0
# process:55.00000000000001%
# [1]
# 分类返回结果为square	真实结果为square
# 目前错误个数： 0.0
# process:57.49999999999999%
# [2]
# 分类返回结果为circle	真实结果为circle
# 目前错误个数： 0.0
# process:60.0%
# [2]
# 分类返回结果为circle	真实结果为circle
# 目前错误个数： 0.0
# process:62.5%
# [2]
# 分类返回结果为circle	真实结果为circle
# 目前错误个数： 0.0
# process:65.0%
# [1]
# 分类返回结果为square	真实结果为square
# 目前错误个数： 0.0
# process:67.5%
# [1]
# 分类返回结果为square	真实结果为square
# 目前错误个数： 0.0
# process:70.0%
# [1]
# 分类返回结果为square	真实结果为square
# 目前错误个数： 0.0
# process:72.5%
# [2]
# 分类返回结果为circle	真实结果为circle
# 目前错误个数： 0.0
# process:75.0%
# [2]
# 分类返回结果为circle	真实结果为circle
# 目前错误个数： 0.0
# process:77.5%
# [2]
# 分类返回结果为circle	真实结果为circle
# 目前错误个数： 0.0
# process:80.0%
# [2]
# 分类返回结果为circle	真实结果为circle
# 目前错误个数： 0.0
# process:82.5%
# [1]
# 分类返回结果为square	真实结果为square
# 目前错误个数： 0.0
# process:85.0%
# [1]
# 分类返回结果为square	真实结果为square
# 目前错误个数： 0.0
# process:87.5%
# [1]
# 分类返回结果为square	真实结果为square
# 目前错误个数： 0.0
# process:90.0%
# [2]
# 分类返回结果为circle	真实结果为circle
# 目前错误个数： 0.0
# process:92.5%
# [1]
# 分类返回结果为square	真实结果为square
# 目前错误个数： 0.0
# process:95.0%
# [1]
# 分类返回结果为square	真实结果为square
# 目前错误个数： 0.0
# process:97.5%
# 总共错了0个数据
# 错误率为0.000000%，正确率为100.000000%

# %%
# visiable
#  TODO 可视化
print(trainSet)
# Out:
# [['75', '2'], ['35', '2'], ['77', '2'], ['3', '2'], ['46', '1'], ['43', '1'], ['22', '1'], ['37', '1'], ['26', '2'], ['6', '1'], ['73', '2'], ['45', '2'], ['53', '1'], ['59', '2'], ['10', '1'], ['8', '2'], ['76', '2'], ['49', '2'], ['24', '1'], ['12', '2'], ['15', '1'], ['64', '1'], ['78', '2'], ['2', '2'], ['57', '1'], ['40', '2'], ['71', '1'], ['14', '2'], ['74', '1'], ['7', '1'], ['66', '2'], ['8', '1'], ['72', '2'], ['65', '2'], ['20', '1'], ['76', '1'], ['50', '1'], ['17', '2'], ['60', '2'], ['59', '1'], ['63', '2'], ['27', '2'], ['25', '1'], ['1', '2'], ['80', '1'], ['67', '1'], ['13', '2'], ['51', '1'], ['79', '1'], ['48', '2'], ['47', '1'], ['62', '1'], ['39', '2'], ['33', '1'], ['75', '1'], ['62', '2'], ['78', '1'], ['34', '2'], ['69', '2'], ['4', '2'], ['23', '1'], ['19', '2'], ['1', '1'], ['73', '1'], ['57', '2'], ['53', '2'], ['68', '1'], ['28', '1'], ['40', '1'], ['20', '2'], ['55', '1'], ['44', '1'], ['43', '2'], ['36', '1'], ['34', '1'], ['31', '2'], ['47', '2'], ['50', '2'], ['32', '2'], ['48', '1'], ['56', '1'], ['25', '2'], ['55', '2'], ['42', '1'], ['35', '1'], ['66', '1'], ['11', '2'], ['77', '1'], ['68', '2'], ['19', '1'], ['37', '2'], ['4', '1'], ['46', '2'], ['38', '2'], ['22', '2'], ['70', '1'], ['6', '2'], ['5', '1'], ['23', '2'], ['2', '1'], ['67', '2'], ['51', '2'], ['41', '2'], ['10', '2'], ['12', '1'], ['60', '1'], ['18', '2'], ['29', '2'], ['5', '2'], ['61', '2'], ['14', '1'], ['58', '2'], ['28', '2'], ['18', '1'], ['36', '2'], ['3', '1'], ['42', '2'], ['54', '2'], ['70', '2'], ['52', '2'], ['30', '2'], ['31', '1'], ['74', '2'], ['39', '1'], ['52', '1'], ['13', '1'], ['27', '1'], ['16', '2'], ['64', '2'], ['24', '2'], ['21', '1'], ['30', '1'], ['17', '1'], ['45', '1'], ['65', '1'], ['44', '2'], ['16', '1'], ['15', '2'], ['41', '1'], ['54', '1'], ['63', '1'], ['32', '1'], ['9', '1'], ['58', '1'], ['33', '2'], ['49', '1'], ['11', '1'], ['38', '1'], ['71', '2'], ['7', '2'], ['72', '1'], ['21', '2'], ['61', '1'], ['29', '1'], ['69', '1'], ['26', '1'], ['80', '2'], ['79', '2'], ['9', '2'], ['56', '2']]

# %%
# visiable
#  TODO 可视化

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import random

# 绘图展示数据，每类数据点以不同的颜色显示


def showFigure():
    # get y from trainSet
    y_train = []
    for i in range(len(trainSet)):
        y_train.append(trainSet[i][0])
    # get x from trainSet
    x_train = []
    for i in range(len(trainSet)):
        x_train.append(float(trainSet[i][1])+random.random()*0.2-0.1)
    print(x_train)
    # result set
    y_test = []
    for i in range(len(testSet)):
        y_test.append(testSet[i][0])
    x_test = []
    for i in range(len(testSet)):
        x_test.append(float(testSet[i][1])+random.random()*0.2-0.1)
    plt.scatter(x_train, y_train, s=10)
    plt.scatter(x_test, y_test, c="g", s=10)
    # 关闭y轴
    plt.yticks([])
    # x轴标记
    xData = [1, 1.2, 1.4, 1.6, 1.8, 2]
    xLim = ["circle", "", "", "", "", "square"]
    plt.xticks(xData, xLim)
    plt.show()
    return 0


showFigure()
# Out:
