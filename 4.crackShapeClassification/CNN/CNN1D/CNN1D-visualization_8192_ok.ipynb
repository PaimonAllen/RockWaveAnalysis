# %%
import time
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torch.nn.functional as F
import hiddenlayer as h
import sys
from torchviz import make_dot
from torchsummary import summary
import netron
import onnx.utils
import onnx.version_converter

wave = 8192
wavetoChn = int(wave/8)
print(wavetoChn)
flag = True

# https://blog.csdn.net/WildCatFish/article/details/116228950


def set_random_seed(state=1):
    """
        设定随机种子
    :param state: 随机种子值
    :return: None
    """
    gens = (np.random.seed, torch.manual_seed)
    for set_state in gens:
        set_state(state)


def process_data(data):
    """
        处理加载的训练数据DataFrame，去掉id，同时对signals以”，“进行拆分。
    :param data: DataFrame, shape(n, 3)
    :return: np array, shape(n, 206)
    """
    res = []
    for i in range(data.shape[0]):
        x_res = data.iloc[i, 1].split(',')
        label = data.iloc[i, 2]
        x_res.append(label)
        res.append(x_res)
    return np.array(res, dtype=np.float64)


def get_pred_x(data):
    """
        处理需要预测数据的DataFrame
    :param data: DataFrame, shape(n, 2)
    :return: np array, shape(n, 205)
    """
    res = []
    for i in range(data.shape[0]):
        x_res = data.iloc[i, 1].split(',')
        res.append(x_res)
    return np.array(res, dtype=np.float64)


def train_loop(dataloader, model, loss_fn, optimizer):
    """
        模型训练部分
    :param dataloader: 训练数据集
    :param model: 训练用到的模型
    :param loss_fn: 评估用的损失函数
    :param optimizer: 优化器
    :return: None
    """
    for batch, x_y in enumerate(dataloader):
        X, y = x_y[:, :wave].type(torch.float64), torch.tensor(
            x_y[:, wave], dtype=torch.long, device='cuda:1')
        # 开启梯度
        with torch.set_grad_enabled(True):
            # Compute prediction and loss
            print(X.shape)
            pred = model(X.float())
            global flag
            if flag == True:
                summary(model, X.float())
                onnx_path = "CNN1D.onnx"  # 文件名
                # 导出神经网络模型为onnx格式
                input = X.float()
                torch.onnx.export(model.to(device), input,
                                  onnx_path, export_params=True,
                                  opset_version=8)
                # model_file = 'model.onnx'
                # onnx_model = onnx.load(onnx_path)
                # onnx.save(onnx.shape_inference.infer_shapes(onnx_model), onnx_path)
                netron.start(onnx_path)  # 启动netron
                flag = False
            loss = loss_fn(pred, y)
            optimizer.zero_grad()
            # Backpropagation
            loss.backward()
            optimizer.step()


def test_loop(dataloader, model, loss_fn):
    """
        模型测试部分
    :param dataloader: 测试数据集
    :param model: 测试模型
    :param loss_fn: 损失函数
    :return: None
    """
    size = len(dataloader.dataset)
    test_loss, correct, l1_loss = 0, 0, 0
    # 用来计算abs-sum. 等于PyTorch L1Loss-->
    # https://pytorch.org/docs/stable/generated/torch.nn.L1Loss.html#torch.nn.L1Loss
    l1loss_fn = AbsSumLoss()
    with torch.no_grad():   # 关掉梯度
        model.eval()
        for x_y in dataloader:
            X, y = x_y[:, :wave].type(torch.float64), torch.tensor(
                x_y[:, wave], dtype=torch.long, device='cuda:1')
            # 注意Y和y的区别, Y用来计算L1 loss, y是CrossEntropy loss.
            Y = torch.zeros(size=(len(y), 6), device='cuda:1')
            for i in range(len(Y)):
                Y[i][y[i]] = 1

            pred = model(X.float())
            # summary(pred)
            test_loss += loss_fn(pred, y).item()    # 这个是CrossEntropy loss
            l1_loss += l1loss_fn(pred, Y).item()    # 这个是abs-sum/L1 loss
            # 这个是计算准确率的, 取概率最大值的下标.
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    test_loss /= size   # 等于CrossEntropy的reduction='mean', 这里有些多此一举可删掉.
    correct /= size
    print(
        f"Test Results:\nAccuracy: {(100*correct):>0.1f}% abs-sum loss: {l1_loss:>8f} CroEtr loss: {test_loss:>8f}")


def prediction(net, loss):
    """
        对数据进行预测
    :param net: 训练好的模型
    :param loss: 模型的测试误差值, 不是损失函数. 可以去掉, 这里是用来给预测数据命名方便区分.
    :return: None
    """
    with torch.no_grad():
        net.eval()
        pred_loader = torch.utils.data.DataLoader(dataset=pred_data)
        res = []
        for x in pred_loader:
            x = torch.tensor(x, device='cuda:1', dtype=torch.float64)
            output = net(x.float())
            res.append(output.cpu().numpy().tolist())

        res = [i[0] for i in res]
        res_df = pd.DataFrame(
            res, columns=['label_1', 'label_2', 'label_3', 'label_4', 'label_5', 'label_6'])
        res_df.insert(0, 'id', value=range(10, 12000))

        res_df.to_csv('res-loss '+str(loss)+'.csv', index=False)


class Model(nn.Module):
    def __init__(self):
        """
            CNN模型构造
        """
        super(Model, self).__init__()
        self.conv_layer1 = nn.Sequential(
            # input shape(32, 1, 256) -> [batch_size, channel, features]64 1 8192
            # 参考->https://pytorch.org/docs/stable/generated/torch.nn.Conv1d.html#torch.nn.Conv1d
            nn.Conv1d(in_channels=1, out_channels=16, kernel_size=3,
                      padding=1),   # 卷积后(32, 16, 256)64 16 8192
            nn.BatchNorm1d(16),
            nn.ReLU()
        )
        # 下采样down-sampling
        self.sample_layer1 = nn.Sequential(
            # input shape(32, 16, 256) 8192
            nn.Conv1d(in_channels=16, out_channels=32,
                      kernel_size=3, padding=1),
            nn.BatchNorm1d(32),
            nn.ReLU(),
            # size随便选的, 这里output应该是(32, 32, 128) 64 32 4096
            nn.MaxPool1d(kernel_size=2, stride=2),
        )

        self.conv_layer2 = nn.Sequential(
            nn.Conv1d(in_channels=32, out_channels=64, kernel_size=3,
                      padding=1),   # 输出(32, 64, 128) 64 64 4096
            nn.BatchNorm1d(64),
            nn.ReLU()
        )

        self.sample_layer2 = nn.Sequential(
            nn.Conv1d(in_channels=64, out_channels=128, kernel_size=3,
                      padding=1),  # 输出(32, 128, 128) 64 128 4096
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),  # 输出(32, 64, 64) 2048
        )

        self.conv_layer3 = nn.Sequential(
            nn.Conv1d(in_channels=128, out_channels=256, kernel_size=3,
                      padding=1),  # 输出(32, 256, 64) 84 256 2048
            nn.BatchNorm1d(256),
            nn.ReLU()
        )

        self.sample_layer3 = nn.Sequential(
            nn.Conv1d(in_channels=256, out_channels=512, kernel_size=3,
                      padding=1),  # 输出(32, 512, 64) 64 512 2048
            nn.BatchNorm1d(512),
            nn.ReLU(),
            # 输出(32, 512, 32) 64 512 1024
            nn.MaxPool1d(kernel_size=2, stride=2),
        )
        self.full_layer = nn.Sequential(
            # nn.Linear(in_features=512*wavetoChn, out_features=64*wavetoChn),
            # nn.Dropout(0.5),
            # nn.ReLU(),
            # nn.Linear(in_features=128*wavetoChn, out_features=32*wavetoChn),
            # nn.Dropout(0.5),
            # nn.ReLU(),
            nn.Linear(in_features=512*wavetoChn, out_features=6)
        )
        # 全连接层
        # self.full_layer = nn.Sequential(
        #     nn.Linear(in_features=512*wavetoChn, out_features=256*wavetoChn),
        #     nn.ReLU(),
        #     nn.Linear(in_features=256*wavetoChn, out_features=128*wavetoChn),
        #     nn.ReLU(),
        #     nn.Linear(in_features=128*wavetoChn, out_features=64*wavetoChn),
        #     nn.ReLU(),
        #     nn.Linear(in_features=64*wavetoChn, out_features=6)
        # )
        # 这个是输出label预测概率, 不知道这写法对不对
        self.pred_layer = nn.Softmax(dim=1)

    def forward(self, x):
        """
            前向传播
        :param x: batch
        :return: training == Ture 返回的是全连接层输出， training == False 加上一个Softmax(), 返回各个label概率.
        """
        x = x.unsqueeze(
            dim=1)  # 升维. input shape(32, 205), output shape(32, 1, 205)
        x = self.conv_layer1(x)
        x = self.sample_layer1(x)
        x = self.conv_layer2(x)
        x = self.sample_layer2(x)
        x = self.conv_layer3(x)
        x = self.sample_layer3(x)
        x = x.view(x.size(0), -1)   # output(32, 12800)
        x = self.full_layer(x)

        if self.training:
            # CrossEntropyLoss自带LogSoftmax, 训练的时候不用输出概率(我也不知道这个写法对不对, 我是试错出来的.)
            return x
        else:
            return self.pred_layer(x)


class AbsSumLoss(nn.Module):
    def __init__(self):
        """
            可以直接用PyTorch的nn.L1Loss, 这个我写的时候不知道。
        """
        super(AbsSumLoss, self).__init__()

    def forward(self, output, target):
        loss = F.l1_loss(target, output, reduction='sum')

        return loss


if __name__ == '__main__':

    set_random_seed(1996)   # 设定随机种子
    # 加载数据集
    data = pd.read_csv('../dataset/train1/train1.csv')
    data = process_data(data)
    pred_data = pd.read_csv('../dataset/train1/test1.csv')
    pred_data = get_pred_x(pred_data)

    # 初始化模型
    lr_rate = 1e-5
    w_decay = 1e-6
    n_epoch = 100
    b_size = 64
    device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')
    # device = 'cpu'
    net = Model()
    net.to(device)
    optimizer = torch.optim.Adam(
        params=net.parameters(), lr=lr_rate, weight_decay=w_decay)
    loss_fn = nn.CrossEntropyLoss(reduction='sum')
    print(Model)

    # 拆分训练测试集
    train, test = train_test_split(data, test_size=0.3)
    train, test = torch.cuda.FloatTensor(train), torch.cuda.FloatTensor(test)
    train = train.to(device)
    test = test.to(device)
    train_loader = torch.utils.data.DataLoader(
        dataset=train, batch_size=b_size)
    test_loader = torch.utils.data.DataLoader(dataset=test, batch_size=b_size)

    # vis_graph = h.build_graph(net,[8192])   # 获取绘制图像的对象
    # vis_graph.theme = h.graph.THEMES["blue"].copy()     # 指定主题颜色
    # vis_graph.save("./demo1.png")   # 保存图像的路径
    # print(train_loader.shape)

    # summary(net, input_size=(8192))
    # net1 = Model()
    # net1.to(device)
    # print(Model.summary())
    # summary(net1, input_size=[(8192, 64)])
    # summary(net1, ((8192,64)))
    # sampledata = torch.cuda.FloatTensor(32, 8192)
    # sampledata=sampledata.to(device)
    # # 看看输出结果对不对
    # out = net1(sampledata)
    # out=
    # print(out)
    # sys.exit()

    for epoch in range(n_epoch):
        start = time.time()
        print(f"\n----------Epoch {epoch + 1}----------")
        train_loop(train_loader, net, loss_fn, optimizer)
        test_loop(test_loader, net, loss_fn)
        end = time.time()
        print('training time: ', end-start)

    # predict
# Out:
# 1024
# <class '__main__.Model'>
#
# ----------Epoch 1----------
# torch.Size([64, 8192])
# /tmp/ipykernel_1063095/3962532631.py:73: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X, y = x_y[:, :wave].type(torch.float64), torch.tensor(
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Sequential: 1-1                        [-1, 16, 8192]            --
# |    └─Conv1d: 2-1                       [-1, 16, 8192]            64
# |    └─BatchNorm1d: 2-2                  [-1, 16, 8192]            32
# |    └─ReLU: 2-3                         [-1, 16, 8192]            --
# ├─Sequential: 1-2                        [-1, 32, 4096]            --
# |    └─Conv1d: 2-4                       [-1, 32, 8192]            1,568
# |    └─BatchNorm1d: 2-5                  [-1, 32, 8192]            64
# |    └─ReLU: 2-6                         [-1, 32, 8192]            --
# |    └─MaxPool1d: 2-7                    [-1, 32, 4096]            --
# ├─Sequential: 1-3                        [-1, 64, 4096]            --
# |    └─Conv1d: 2-8                       [-1, 64, 4096]            6,208
# |    └─BatchNorm1d: 2-9                  [-1, 64, 4096]            128
# |    └─ReLU: 2-10                        [-1, 64, 4096]            --
# ├─Sequential: 1-4                        [-1, 128, 2048]           --
# |    └─Conv1d: 2-11                      [-1, 128, 4096]           24,704
# |    └─BatchNorm1d: 2-12                 [-1, 128, 4096]           256
# |    └─ReLU: 2-13                        [-1, 128, 4096]           --
# |    └─MaxPool1d: 2-14                   [-1, 128, 2048]           --
# ├─Sequential: 1-5                        [-1, 256, 2048]           --
# |    └─Conv1d: 2-15                      [-1, 256, 2048]           98,560
# |    └─BatchNorm1d: 2-16                 [-1, 256, 2048]           512
# |    └─ReLU: 2-17                        [-1, 256, 2048]           --
# ├─Sequential: 1-6                        [-1, 512, 1024]           --
# |    └─Conv1d: 2-18                      [-1, 512, 2048]           393,728
# |    └─BatchNorm1d: 2-19                 [-1, 512, 2048]           1,024
# |    └─ReLU: 2-20                        [-1, 512, 2048]           --
# |    └─MaxPool1d: 2-21                   [-1, 512, 1024]           --
# ├─Sequential: 1-7                        [-1, 6]                   --
# |    └─Linear: 2-22                      [-1, 6]                   3,145,734
# ├─Softmax: 1-8                           [-1, 6]                   --
# ==========================================================================================
# Total params: 3,672,582
# Trainable params: 3,672,582
# Non-trainable params: 0
# Total mult-adds (G): 1.15
# ==========================================================================================
# Input size (MB): 2.00
# Forward/backward pass size (MB): 42.00
# Params size (MB): 14.01
# Estimated Total Size (MB): 58.01
# ==========================================================================================
# Serving 'CNN1D.onnx' at http://localhost:8080
# /home/tzr/.local/lib/python3.8/site-packages/torch/onnx/utils.py:687: UserWarning: Constant folding - unsupported opset version. Constant folding not applied. (Triggered internally at ../torch/csrc/jit/passes/onnx/constant_fold.cpp:345.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# /home/tzr/.local/lib/python3.8/site-packages/torch/onnx/utils.py:1178: UserWarning: Constant folding - unsupported opset version. Constant folding not applied. (Triggered internally at ../torch/csrc/jit/passes/onnx/constant_fold.cpp:345.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# /tmp/ipykernel_1063095/3962532631.py:117: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X, y = x_y[:, :wave].type(torch.float64), torch.tensor(
# Test Results:
# Accuracy: 15.7% abs-sum loss: 500.434601 CroEtr loss: 1.793852
# training time:  5.19049596786499
#
# ----------Epoch 2----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 15.7% abs-sum loss: 500.608543 CroEtr loss: 1.794869
# training time:  2.1914329528808594
#
# ----------Epoch 3----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 15.7% abs-sum loss: 500.860168 CroEtr loss: 1.795715
# training time:  2.1929028034210205
#
# ----------Epoch 4----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 15.7% abs-sum loss: 501.224632 CroEtr loss: 1.796567
# training time:  2.1936023235321045
#
# ----------Epoch 5----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 15.7% abs-sum loss: 501.589699 CroEtr loss: 1.797378
# training time:  2.192375898361206
#
# ----------Epoch 6----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 15.7% abs-sum loss: 501.866829 CroEtr loss: 1.798015
# training time:  2.1975910663604736
#
# ----------Epoch 7----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 15.7% abs-sum loss: 502.025124 CroEtr loss: 1.798411
# training time:  2.196681499481201
#
# ----------Epoch 8----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 15.7% abs-sum loss: 502.079689 CroEtr loss: 1.798584
# training time:  2.1940395832061768
#
# ----------Epoch 9----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 15.7% abs-sum loss: 502.060715 CroEtr loss: 1.798596
# training time:  2.192967176437378
#
# ----------Epoch 10----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 15.7% abs-sum loss: 502.003433 CroEtr loss: 1.798521
# training time:  2.1950623989105225
#
# ----------Epoch 11----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 15.7% abs-sum loss: 501.931137 CroEtr loss: 1.798409
# training time:  2.193743944168091
#
# ----------Epoch 12----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 15.7% abs-sum loss: 501.859886 CroEtr loss: 1.798292
# training time:  2.1932663917541504
#
# ----------Epoch 13----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 15.7% abs-sum loss: 501.797882 CroEtr loss: 1.798189
# training time:  2.1951324939727783
#
# ----------Epoch 14----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 15.7% abs-sum loss: 501.739853 CroEtr loss: 1.798094
# training time:  2.194740056991577
#
# ----------Epoch 15----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 15.7% abs-sum loss: 501.682129 CroEtr loss: 1.798002
# training time:  2.1956207752227783
#
# ----------Epoch 16----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 15.7% abs-sum loss: 501.621712 CroEtr loss: 1.797905
# training time:  2.194383144378662
#
# ----------Epoch 17----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 15.7% abs-sum loss: 501.557930 CroEtr loss: 1.797803
# training time:  2.1963446140289307
#
# ----------Epoch 18----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 15.7% abs-sum loss: 501.490471 CroEtr loss: 1.797694
# training time:  2.1948626041412354
#
# ----------Epoch 19----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 15.7% abs-sum loss: 501.420151 CroEtr loss: 1.797580
# training time:  2.210890769958496
#
# ----------Epoch 20----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 15.7% abs-sum loss: 501.345276 CroEtr loss: 1.797460
# training time:  2.200984477996826
#
# ----------Epoch 21----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 15.7% abs-sum loss: 501.265739 CroEtr loss: 1.797331
# training time:  2.19433856010437
#
# ----------Epoch 22----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 16.7% abs-sum loss: 501.180557 CroEtr loss: 1.797193
# training time:  2.194186210632324
#
# ----------Epoch 23----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 18.0% abs-sum loss: 501.088348 CroEtr loss: 1.797043
# training time:  2.1955184936523438
#
# ----------Epoch 24----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 18.0% abs-sum loss: 500.987274 CroEtr loss: 1.796879
# training time:  2.201469659805298
#
# ----------Epoch 25----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 18.0% abs-sum loss: 500.879395 CroEtr loss: 1.796702
# training time:  2.1950159072875977
#
# ----------Epoch 26----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 18.0% abs-sum loss: 500.763603 CroEtr loss: 1.796511
# training time:  2.1961112022399902
#
# ----------Epoch 27----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 18.0% abs-sum loss: 500.638496 CroEtr loss: 1.796302
# training time:  2.196509599685669
#
# ----------Epoch 28----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 18.0% abs-sum loss: 500.501457 CroEtr loss: 1.796070
# training time:  2.194359540939331
#
# ----------Epoch 29----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 20.7% abs-sum loss: 500.353653 CroEtr loss: 1.795821
# training time:  2.1952545642852783
#
# ----------Epoch 30----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 24.3% abs-sum loss: 500.190193 CroEtr loss: 1.795545
# training time:  2.1979615688323975
#
# ----------Epoch 31----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 27.3% abs-sum loss: 500.015045 CroEtr loss: 1.795249
# training time:  2.1983096599578857
#
# ----------Epoch 32----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 28.0% abs-sum loss: 499.825760 CroEtr loss: 1.794930
# training time:  2.195413112640381
#
# ----------Epoch 33----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 28.0% abs-sum loss: 499.617531 CroEtr loss: 1.794581
# training time:  2.195963144302368
#
# ----------Epoch 34----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 28.0% abs-sum loss: 499.377533 CroEtr loss: 1.794179
# training time:  2.198845624923706
#
# ----------Epoch 35----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 28.0% abs-sum loss: 499.118233 CroEtr loss: 1.793745
# training time:  2.206406593322754
#
# ----------Epoch 36----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 28.0% abs-sum loss: 498.829742 CroEtr loss: 1.793262
# training time:  2.1957814693450928
#
# ----------Epoch 37----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 28.0% abs-sum loss: 498.497360 CroEtr loss: 1.792705
# training time:  2.2036519050598145
#
# ----------Epoch 38----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 28.0% abs-sum loss: 498.137840 CroEtr loss: 1.792109
# training time:  2.2003026008605957
#
# ----------Epoch 39----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 28.0% abs-sum loss: 497.715721 CroEtr loss: 1.791401
# training time:  2.2040627002716064
#
# ----------Epoch 40----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 28.0% abs-sum loss: 497.235512 CroEtr loss: 1.790602
# training time:  2.2107274532318115
#
# ----------Epoch 41----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 28.0% abs-sum loss: 496.682373 CroEtr loss: 1.789699
# training time:  2.1952919960021973
#
# ----------Epoch 42----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 28.0% abs-sum loss: 496.015282 CroEtr loss: 1.788620
# training time:  2.20168399810791
#
# ----------Epoch 43----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 28.0% abs-sum loss: 495.198402 CroEtr loss: 1.787296
# training time:  2.1982977390289307
#
# ----------Epoch 44----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 27.3% abs-sum loss: 494.182091 CroEtr loss: 1.785692
# training time:  2.1959877014160156
#
# ----------Epoch 45----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 24.7% abs-sum loss: 492.902557 CroEtr loss: 1.783687
# training time:  2.197117328643799
#
# ----------Epoch 46----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 21.3% abs-sum loss: 491.318428 CroEtr loss: 1.781233
# training time:  2.1980388164520264
#
# ----------Epoch 47----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 33.0% abs-sum loss: 489.345161 CroEtr loss: 1.778291
# training time:  2.1970973014831543
#
# ----------Epoch 48----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 32.7% abs-sum loss: 486.862610 CroEtr loss: 1.774672
# training time:  2.200758457183838
#
# ----------Epoch 49----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 30.3% abs-sum loss: 483.693069 CroEtr loss: 1.770109
# training time:  2.1982126235961914
#
# ----------Epoch 50----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 26.7% abs-sum loss: 479.666443 CroEtr loss: 1.764418
# training time:  2.204223871231079
#
# ----------Epoch 51----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 26.7% abs-sum loss: 474.570969 CroEtr loss: 1.757198
# training time:  2.195896625518799
#
# ----------Epoch 52----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 26.7% abs-sum loss: 468.642029 CroEtr loss: 1.748837
# training time:  2.1971099376678467
#
# ----------Epoch 53----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 26.7% abs-sum loss: 461.769722 CroEtr loss: 1.738992
# training time:  2.1980984210968018
#
# ----------Epoch 54----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 27.7% abs-sum loss: 454.165421 CroEtr loss: 1.727890
# training time:  2.1995837688446045
#
# ----------Epoch 55----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 34.3% abs-sum loss: 445.646683 CroEtr loss: 1.715378
# training time:  2.19791841506958
#
# ----------Epoch 56----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 35.7% abs-sum loss: 437.044136 CroEtr loss: 1.702587
# training time:  2.1978096961975098
#
# ----------Epoch 57----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 39.3% abs-sum loss: 428.588989 CroEtr loss: 1.690042
# training time:  2.1954030990600586
#
# ----------Epoch 58----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 41.0% abs-sum loss: 420.152996 CroEtr loss: 1.677592
# training time:  2.1975672245025635
#
# ----------Epoch 59----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 45.7% abs-sum loss: 411.549454 CroEtr loss: 1.664961
# training time:  2.1978437900543213
#
# ----------Epoch 60----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 49.7% abs-sum loss: 403.001404 CroEtr loss: 1.652402
# training time:  2.1973726749420166
#
# ----------Epoch 61----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 53.7% abs-sum loss: 394.420406 CroEtr loss: 1.639787
# training time:  2.198751211166382
#
# ----------Epoch 62----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 54.7% abs-sum loss: 385.767113 CroEtr loss: 1.626971
# training time:  2.1996848583221436
#
# ----------Epoch 63----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 55.3% abs-sum loss: 376.941513 CroEtr loss: 1.613772
# training time:  2.1987345218658447
#
# ----------Epoch 64----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 55.0% abs-sum loss: 367.960434 CroEtr loss: 1.600136
# training time:  2.19492506980896
#
# ----------Epoch 65----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 55.3% abs-sum loss: 358.798904 CroEtr loss: 1.585948
# training time:  2.197584867477417
#
# ----------Epoch 66----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 55.3% abs-sum loss: 349.281162 CroEtr loss: 1.570915
# training time:  2.196732997894287
#
# ----------Epoch 67----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 55.3% abs-sum loss: 339.174866 CroEtr loss: 1.554978
# training time:  2.1975979804992676
#
# ----------Epoch 68----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 58.7% abs-sum loss: 328.023457 CroEtr loss: 1.537796
# training time:  2.2020957469940186
#
# ----------Epoch 69----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 67.7% abs-sum loss: 316.039478 CroEtr loss: 1.519549
# training time:  2.199475049972534
#
# ----------Epoch 70----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 69.3% abs-sum loss: 303.345112 CroEtr loss: 1.500342
# training time:  2.1957292556762695
#
# ----------Epoch 71----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 71.0% abs-sum loss: 290.115269 CroEtr loss: 1.480608
# training time:  2.1965370178222656
#
# ----------Epoch 72----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 71.3% abs-sum loss: 276.747189 CroEtr loss: 1.460909
# training time:  2.1973912715911865
#
# ----------Epoch 73----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 72.0% abs-sum loss: 263.678955 CroEtr loss: 1.441892
# training time:  2.196903705596924
#
# ----------Epoch 74----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 72.3% abs-sum loss: 251.336197 CroEtr loss: 1.424152
# training time:  2.197427749633789
#
# ----------Epoch 75----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 72.3% abs-sum loss: 240.032509 CroEtr loss: 1.408089
# training time:  2.1983797550201416
#
# ----------Epoch 76----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 72.3% abs-sum loss: 229.972134 CroEtr loss: 1.393935
# training time:  2.198188304901123
#
# ----------Epoch 77----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([60, 8192])
# Test Results:
# Accuracy: 72.3% abs-sum loss: 221.237629 CroEtr loss: 1.381745
# training time:  2.197194814682007
#
# ----------Epoch 78----------
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
# torch.Size([64, 8192])
